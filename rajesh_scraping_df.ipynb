# %% [markdown]
# <a href="https://colab.research.google.com/github/Divs2930/NarrativeReseach/blob/main/rajesh_scraping_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/final_rajesh.csv')

# %%
df.head()
# Out:
#                                               images  \
# 0                                                 []
# 1  ['https://nitter.poast.org/pic/orig/media%2FGN...
# 2  ['https://nitter.poast.org/pic/orig/media%2FGN...
# 3  ['https://nitter.poast.org/pic/orig/media%2FGN...
# 4  ['https://nitter.poast.org/pic/orig/media%2FGN...
#
#                  retweet_of  handle_original_tweet  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3  Rajesh Agrawal retweeted                    NaN
# 4  Rajesh Agrawal retweeted                    NaN
#
#             handle_original_tweet_name handle_original_tweet_user  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# ...

# %%
df['type_of_tweet'].unique()
# Out:
# array(['tweet', 'retweet', 'quote'], dtype=object)

# %%
df.isna().sum()
# Out:
# images                          0
# retweet_of                     55
# handle_original_tweet         134
# handle_original_tweet_name     55
# handle_original_tweet_user     43
# type_of_tweet                   0
# time_elapsed                    0
# comments_on_tweet              42
# retweets_on_tweet              22
# quote_on_tweet                 63
# likes_on_tweet                  3
# text                            0
# link                            0
# profile                         0
# profile_handle                  0
# posts                           0
# likes                           0
# followers                       0
# following                       0
# user                            0
# username                        0
# quote_original_text           122
# dtype: int64

# %%
df.describe()
# Out:
#        handle_original_tweet   posts   likes  followers  following
# count                    0.0   134.0   134.0      134.0      134.0
# mean                     NaN  6894.0  1524.0    10765.0     1068.0
# std                      NaN     0.0     0.0        0.0        0.0
# min                      NaN  6894.0  1524.0    10765.0     1068.0
# 25%                      NaN  6894.0  1524.0    10765.0     1068.0
# 50%                      NaN  6894.0  1524.0    10765.0     1068.0
# 75%                      NaN  6894.0  1524.0    10765.0     1068.0
# max                      NaN  6894.0  1524.0    10765.0     1068.0
